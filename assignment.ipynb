# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **KAKAEDE JAMES**
# I AM A STUDENT

# %% [markdown]
# *I am interested in data science becuause i desire to want to improve my decision making ability and also to improve business income and profitability*

# %% [markdown]
# # In cell 5, i will be carrying out a simple arithmetic; dividing 100 by 10

# %%
100/10
# Out:
# 10.0

# %% [markdown]
# * one
# * two
# * three
# * four
#     * 1
#     * 2
#     * 3
#     * 4
#
#
# 1. james
# 2. peter
# 3. paul
#
#
# |name||age||income|
# |----||---||------|
# |james||31||21,000|
# |bridget||27||30,00|
# |judith||25||20,000|

# %% [markdown]
# * one
# * two
# * three
# * four
#     * 1
#     * 2
#     * 3
#     * 4
#
#
# 1. james
# 2. peter
# 3. paul
#
#
# |name||age||income|
# |----||---||------|
# |james||31||21,000|
# |bridget||27||30,00|
# |judith||25||20,000|
